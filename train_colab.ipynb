# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import torch
print(f"✅ CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"✅ GPU: {torch.cuda.get_device_name(0)}")
    print(f"✅ Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
# Out:
# ✅ CUDA available: True
# ✅ GPU: Tesla T4
# ✅ Memory: 15.6 GB

# %%
# Install required packages
# !pip install -q transformers torch scikit-learn pandas tqdm

print("✅ All packages installed!")
# Out:
# ✅ All packages installed!

# %%
# !git clone https://github.com/hitman567/email-classifier.git
# Out:
# Cloning into 'email-classifier'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 26 (delta 6), reused 21 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 20.56 KiB | 20.56 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# %cd email-classifier
# Out:
# /content/email-classifier

# %%
# !ls -ls src/
# Out:
# total 28
#  4 -rw-r--r-- 1 root root  3810 May 25 03:51 baseline.py
#  4 -rw-r--r-- 1 root root  3879 May 25 03:51 data_loader.py
# 20 -rw-r--r-- 1 root root 16683 May 25 03:51 train.py

# %%
# Check if files exist
import os

files_to_check = [
    'src/data_loader.py',
    'src/baseline.py',
    'src/train.py',
    'requirements.txt'
]

print("📂 Checking files...")
for file in files_to_check:
    exists = "✅" if os.path.exists(file) else "❌"
    print(f"   {exists} {file}")

# Check if data exists
if os.path.exists('data/processed/train.csv'):
    print("\n✅ Data already exists!")
else:
    print("\n⚠️  Data needs to be downloaded")
# Out:
# 📂 Checking files...
#    ✅ src/data_loader.py
#    ✅ src/baseline.py
#    ✅ src/train.py
#    ✅ requirements.txt
#
# ⚠️  Data needs to be downloaded

# %%
# Create missing directories
# !mkdir -p data/raw
# !mkdir -p data/processed
# !mkdir -p models
# !mkdir -p outputs

print("✅ Directories created!")

# Verify
# !ls -la data/
# Out:
# ✅ Directories created!
# total 16
# drwxr-xr-x 4 root root 4096 May 25 03:54 .
# drwxr-xr-x 7 root root 4096 May 25 03:54 ..
# drwxr-xr-x 2 root root 4096 May 25 03:54 processed
# drwxr-xr-x 2 root root 4096 May 25 03:54 raw

# %%
# !python src/data_loader.py
# Out:
# ...
# EMAIL CLASSIFIER - DATA PREPARATION
# ...
# Downloaded 11314 training samples
# Downloaded 7532 testing samples
# Categories (20): ['alt.atheism', 'comp.graphics', 'comp.os.ms-windows.misc', 'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware']...
#
#  Dataset Statistics:
# Total samples: 17919
# Avg text length: 1229 characters
#
# 📁 Split sizes:
#    Train: 12543
#    Val:   2688
#    Test:  2688
# Data saved to data/processed
#
# ...
# Dataset ready!
# ...

# %%
# Quick fix - modify the import in train.py
# !sed -i 's/from src.data_loader/from data_loader/' src/train.py

# Verify the fix
# !grep "from data_loader" src/train.py

print("✅ Import fixed!")
# Out:
# from data_loader import load_dataset
# ✅ Import fixed!

# %%
# !python src/train.py
# Out:
# ...
#  ROBERTA FINE_TUNING FOR EMAIL CLASSIFICATION
# ...
#
# Loading dataset...
#    Train: 12543 samples
#    Val:   2688 samples
#    Test:  2688 samples
#    Categories: 20
# Loaded 20 categories
# Starting RoBERTa Fine-tuning
# ...
# Device: cuda
#    GPU: Tesla T4
#    Memory: 15.6 GB
#
# Loading roberta-base...
# ...
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 131kB/s]
# vocab.json: 899kB [00:00, 38.5MB/s]
# merges.txt: 456kB [00:00, 3.96MB/s]
# tokenizer.json: 1.36MB [00:00, 6.37MB/s]
# config.json: 100% 481/481 [00:00<00:00, 3.15MB/s]
# model.safetensors: 100% 499M/499M [00:04<00:00, 113MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 939.41it/s, Materializing param=roberta.encoder.layer.11.output.dense.weight]               [00:00<00:00, 3075.67it/s, Materializing param=roberta.encoder.layer.0.intermediate.dense.weight]
# RobertaForSequenceClassification LOAD REPORT from: roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# ...
